# %%
import pandas as pd

# %%
df_nyc_311 = pd.read_csv('data/nyc_311_2024_2025_sample.csv', index_col="unique_key")
df_median_rent = pd.read_csv('data/medianAskingRent_All.csv')

# %%
print(df_nyc_311.shape)
print(df_median_rent.shape)
# Out:
# (71755, 42)
# (198, 191)

# %%
df_median_rent.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket   3200.0   3200.0   3015.0
# 1          All Midtown  Manhattan  submarket   2875.0   2800.0   2800.0
# 2  All Upper East Side  Manhattan  submarket   2450.0   2450.0   2400.0
# 3  All Upper Manhattan  Manhattan  submarket   1825.0   1800.0   1795.0
# 4  All Upper West Side  Manhattan  submarket   2895.0   2800.0   2750.0
#
#    2010-04  2010-05  2010-06  2010-07  ...  2024-11  2024-12  2025-01  \
# 0   3100.0   3100.0   3200.0   3195.0  ...   4895.0   4900.0   4998.0
# 1   2850.0   2895.0   2950.0   3000.0  ...   4400.0   4500.0   4504.0
# 2   2500.0   2565.0   2570.0   2595.0  ...   3950.0   3950.0   3950.0
# 3   1800.0   1823.0   1850.0   1875.0  ...   2850.0   2850.0   2895.0
# 4   2800.0   2800.0   2795.0   2800.0  ...   4295.0   4400.0   4432.0
#
#    2025-02  2025-03  2025-04  2025-05  2025-06  2025-07  2025-08
# 0   5000.0   5000.0   5158.0   5250.0   5300.0   5437.0   5450.0
# 1   4595.0   4586.0   4683.0   4750.0   4850.0   4875.0   4844.0
# 2   4000.0   3995.0   4000.0   4156.0   4200.0   4200.0   4250.0
# 3   2875.0   2900.0   3000.0   3195.0   3236.0   3300.0   3225.0
# 4   4450.0   4500.0   4500.0   4500.0   4700.0   4800.0   4850.0
#
# [5 rows x 191 columns]

# %%
df_nyc_311.head(5)
# Out:
#                        created_date              closed_date agency  \
# unique_key
# 59945453    2024-01-06T13:06:35.000  2024-01-19T18:34:37.000    HPD
# 59949590    2024-01-06T14:31:27.000  2024-01-07T13:03:02.000    HPD
# 59957878    2024-01-08T07:45:53.000  2024-01-08T07:58:13.000   NYPD
# 59940883    2024-01-05T14:54:38.000  2024-01-05T20:48:26.000    HPD
# 59957240    2024-01-07T09:51:51.000  2024-03-08T16:55:31.000    HPD
#
#                                                   agency_name  \
# unique_key
# 59945453    Department of Housing Preservation and Develop...
# 59949590    Department of Housing Preservation and Develop...
# 59957878                      New York City Police Department
# 59940883    Department of Housing Preservation and Develop...
# 59957240    Department of Housing Preservation and Develop...
#
#                  complaint_type        descriptor               location_type  \
# unique_key
# 59945453               ELECTRIC       NO LIGHTING        RESIDENTIAL BUILDING
# 59949590         HEAT/HOT WATER   ENTIRE BUILDING        RESIDENTIAL BUILDING
# 59957878    Noise - Residential  Banging/Pounding  Residential Building/House
# 59940883         HEAT/HOT WATER    APARTMENT ONLY        RESIDENTIAL BUILDING
# 59957240              APPLIANCE      REFRIGERATOR        RESIDENTIAL BUILDING
#
#             incident_zip       incident_address       street_name  ...  \
# unique_key                                                         ...
# 59945453         10460.0    805 FAIRMOUNT PLACE   FAIRMOUNT PLACE  ...
# 59949590         10462.0  2040 BRONXDALE AVENUE  BRONXDALE AVENUE  ...
# 59957878         10454.0   640 EAST  137 STREET  EAST  137 STREET  ...
# 59940883         10456.0       1384 BOSTON ROAD       BOSTON ROAD  ...
# 59957240         10452.0     1040 GERARD AVENUE     GERARD AVENUE  ...
#
#            taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# unique_key
# 59945453                     NaN                 NaN                      NaN
# 59949590                     NaN                 NaN                      NaN
# 59957878                     NaN                 NaN                      NaN
# 59940883                     NaN                 NaN                      NaN
# 59957240                     NaN                 NaN                      NaN
#
#            road_ramp bridge_highway_segment   latitude  longitude  \
# unique_key
# 59945453         NaN                    NaN  40.842664 -73.888943
# 59949590         NaN                    NaN  40.850795 -73.866537
# 59957878         NaN                    NaN  40.805086 -73.915530
# 59940883         NaN                    NaN  40.832588 -73.898197
# 59957240         NaN                    NaN  40.831529 -73.922568
#
#                                                    location  \
# unique_key
# 59945453    \n,  \n(40.842663807026554, -73.88894325756999)
# 59949590    \n,  \n(40.850794587937656, -73.86653703997725)
# 59957878    \n,  \n(40.805086455448915, -73.91552995791113)
# 59940883     \n,  \n(40.83258827381062, -73.89819654318568)
# 59957240     \n,  \n(40.83152853960675, -73.92256816978937)
#
#                   quarter_start          quarter_end
# unique_key
# 59945453    2024-01-01T00:00:00  2024-03-31T23:59:59
# 59949590    2024-01-01T00:00:00  2024-03-31T23:59:59
# 59957878    2024-01-01T00:00:00  2024-03-31T23:59:59
# 59940883    2024-01-01T00:00:00  2024-03-31T23:59:59
# 59957240    2024-01-01T00:00:00  2024-03-31T23:59:59
#
# [5 rows x 42 columns]

# %%
list_of_relevant_columns = ['created_date', 'closed_date', 'complaint_type',
                            'descriptor', 'status', 'resolution_description',
                            'resolution_action_updated_date', 'borough',
                            'community_board', 'incident_zip', 
                            'incident_address', 'street_name', 'city',
                            'latitude', 'longitude']

df_nyc_311_selected = df_nyc_311[list_of_relevant_columns]

# %%
date_columns = [col for col in df_median_rent.columns if col.startswith('2024') or col.startswith('2025')]
df_median_rent_selected = df_median_rent[df_median_rent.columns[:3].to_list() + date_columns].copy()

# %%
df_nyc_311_selected.head()
# Out:
#                        created_date              closed_date  \
# unique_key
# 59945453    2024-01-06T13:06:35.000  2024-01-19T18:34:37.000
# 59949590    2024-01-06T14:31:27.000  2024-01-07T13:03:02.000
# 59957878    2024-01-08T07:45:53.000  2024-01-08T07:58:13.000
# 59940883    2024-01-05T14:54:38.000  2024-01-05T20:48:26.000
# 59957240    2024-01-07T09:51:51.000  2024-03-08T16:55:31.000
#
#                  complaint_type        descriptor  status  \
# unique_key
# 59945453               ELECTRIC       NO LIGHTING  Closed
# 59949590         HEAT/HOT WATER   ENTIRE BUILDING  Closed
# 59957878    Noise - Residential  Banging/Pounding  Closed
# 59940883         HEAT/HOT WATER    APARTMENT ONLY  Closed
# 59957240              APPLIANCE      REFRIGERATOR  Closed
#
#                                        resolution_description  \
# unique_key
# 59945453    The Department of Housing Preservation and Dev...
# 59949590    The complaint you filed is a duplicate of a co...
# 59957878    The Police Department responded to the complai...
# 59940883    The Department of Housing Preservation and Dev...
# 59957240    The Department of Housing Preservation and Dev...
#
#            resolution_action_updated_date borough community_board  \
# unique_key
# 59945453          2024-01-19T00:00:00.000   BRONX        06 BRONX
# 59949590          2024-01-07T00:00:00.000   BRONX        11 BRONX
# 59957878          2024-01-08T07:58:15.000   BRONX        01 BRONX
# 59940883          2024-01-05T00:00:00.000   BRONX        03 BRONX
# 59957240          2024-03-08T00:00:00.000   BRONX        04 BRONX
#
#             incident_zip       incident_address       street_name   city  \
# unique_key
# 59945453         10460.0    805 FAIRMOUNT PLACE   FAIRMOUNT PLACE  BRONX
# 59949590         10462.0  2040 BRONXDALE AVENUE  BRONXDALE AVENUE  BRONX
# 59957878         10454.0   640 EAST  137 STREET  EAST  137 STREET  BRONX
# 59940883         10456.0       1384 BOSTON ROAD       BOSTON ROAD  BRONX
# 59957240         10452.0     1040 GERARD AVENUE     GERARD AVENUE  BRONX
#
#              latitude  longitude
# unique_key
# 59945453    40.842664 -73.888943
# 59949590    40.850795 -73.866537
# 59957878    40.805086 -73.915530
# 59940883    40.832588 -73.898197
# 59957240    40.831529 -73.922568

# %%
df_nyc_311_selected.describe(include='all')
# Out:
#                    created_date              closed_date   complaint_type  \
# count                     71755                    69690            71755
# unique                    67328                    59509              158
# top     2024-01-08T07:00:00.000  2025-07-08T15:00:00.000  Illegal Parking
# freq                         12                       98            10660
# mean                        NaN                      NaN              NaN
# std                         NaN                      NaN              NaN
# min                         NaN                      NaN              NaN
# 25%                         NaN                      NaN              NaN
# 50%                         NaN                      NaN              NaN
# 75%                         NaN                      NaN              NaN
# max                         NaN                      NaN              NaN
#
#               descriptor  status  \
# count              67991   71755
# unique               682       7
# top     Loud Music/Party  Closed
# freq               11236   69787
# mean                 NaN     NaN
# std                  NaN     NaN
# min                  NaN     NaN
# 25%                  NaN     NaN
# 50%                  NaN     NaN
# 75%                  NaN     NaN
# max                  NaN     NaN
#
#                                    resolution_description  \
# count                                               69736
# unique                                                484
# top     The Police Department responded to the complai...
# freq                                                10096
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        resolution_action_updated_date   borough community_board  incident_zip  \
# count                           70836     71755           71755  71152.000000
# unique                          52595         5              76           NaN
# top           2024-01-08T00:00:00.000  BROOKLYN        12 BRONX           NaN
# freq                              415     21066            3968           NaN
# mean                              NaN       NaN             NaN  10832.039324
# std                               NaN       NaN             NaN    540.152559
# min                               NaN       NaN             NaN     83.000000
# 25%                               NaN       NaN             NaN  10452.000000
# 50%                               NaN       NaN             NaN  11204.000000
# 75%                               NaN       NaN             NaN  11237.000000
# max                               NaN       NaN             NaN  11697.000000
#
#             incident_address       street_name      city      latitude  \
# count                  69520             69518     68305  70700.000000
# unique                 43348              5168        50           NaN
# top     655 EAST  230 STREET  EAST  230 STREET  BROOKLYN           NaN
# freq                    2336              2679     20187           NaN
# mean                     NaN               NaN       NaN     40.738644
# std                      NaN               NaN       NaN      0.087374
# min                      NaN               NaN       NaN     40.499937
# 25%                      NaN               NaN       NaN     40.674798
# 50%                      NaN               NaN       NaN     40.729463
# 75%                      NaN               NaN       NaN     40.817426
# max                      NaN               NaN       NaN     40.912828
#
#            longitude
# count   70700.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      -73.918228
# std         0.076807
# min       -74.253219
# 25%       -73.962663
# 50%       -73.922512
# 75%       -73.865904
# max       -73.701308

# %%
# Analysis of missing values with percentages
missing_values = df_nyc_311_selected.isna().sum().sort_values(ascending=False)
missing_percentage = (df_nyc_311_selected.isna().sum() / len(df_nyc_311_selected) * 100).sort_values(ascending=False)

# Creating a DataFrame for convenient display
missing_data = pd.DataFrame({
    'Missing_Count': missing_values,
    'Missing_Percentage': missing_percentage
})

# Only show columns with empty values
missing_data = missing_data[missing_data['Missing_Count'] > 0]

print(f"Total number of rows in the dataset: {len(df_nyc_311)}")
print("\nAnalysis of empty values:")
print(missing_data.round(2))
# Out:
# Total number of rows in the dataset: 71755
#
# Analysis of empty values:
#                                 Missing_Count  Missing_Percentage
# descriptor                               3764                5.25
# city                                     3450                4.81
# street_name                              2237                3.12
# incident_address                         2235                3.11
# closed_date                              2065                2.88
# resolution_description                   2019                2.81
# latitude                                 1055                1.47
# longitude                                1055                1.47
# resolution_action_updated_date            919                1.28
# incident_zip                              603                0.84

# %%
print( "Duplicate rows in rent data:",df_median_rent_selected.duplicated().sum())
print( "Duplicate rows in 311 data:",df_nyc_311_selected.duplicated().sum())
# Out:
# Duplicate rows in rent data: 0
# Duplicate rows in 311 data: 168

# %%
df_nyc_311_selected = df_nyc_311_selected.drop_duplicates()
df_nyc_311_selected.shape
# Out:
# (71587, 15)

# %%
# Convert date columns to datetime format
df_nyc_311_selected['created_date'] = pd.to_datetime(df_nyc_311_selected['created_date'], errors='coerce')
df_nyc_311_selected['closed_date'] = pd.to_datetime(df_nyc_311_selected['closed_date'], errors='coerce')
df_nyc_311_selected['resolution_action_updated_date'] = pd.to_datetime(df_nyc_311_selected['resolution_action_updated_date'], errors='coerce')

print(f"Number of rows with created_date > closed_date, that will be removed: {df_nyc_311_selected[df_nyc_311_selected['created_date'] > df_nyc_311_selected['closed_date']].shape[0]}")
df_nyc_311_selected = df_nyc_311_selected[(df_nyc_311_selected['created_date'] <= df_nyc_311_selected['closed_date']) | (df_nyc_311_selected['closed_date'].isna())]
# Out:
# Number of rows with created_date > closed_date, that will be removed: 21

# %%
unique_counts = df_nyc_311_selected.nunique()
columns_to_check = unique_counts[unique_counts < 1000].index.to_list()

for col in columns_to_check:
    print(f"Value counts for column '{col}':")
    print(df_nyc_311_selected[col].value_counts())
    print("\n")
# Out:
# Value counts for column 'complaint_type':
# complaint_type
# Illegal Parking                10660
# Noise - Residential             9707
# HEAT/HOT WATER                  4894
# Noise - Street/Sidewalk         3983
# Blocked Driveway                3507
#                                ...
# Taxi Compliment                    1
# Unsanitary Animal Facility         1
# Tobacco or Non-Tobacco Sale        1
# Pet Sale                           1
# Retailer Complaint                 1
# Name: count, Length: 158, dtype: int64
#
#
# Value counts for column 'descriptor':
# descriptor
# Loud Music/Party            11236
# ENTIRE BUILDING              3223
# Blocked Hydrant              3052
# Banging/Pounding             2523
# No Access                    2495
#                             ...
# Donation Collection Bin         1
# Online or Mail Order            1
# Hangers                         1
# Animal Odor                     1
# Sales to Minors Under 21        1
# Name: count, Length: 681, dtype: int64
#
#
# Value counts for column 'status':
# status
# Closed         69625
# In Progress     1189
# Open             468
# Assigned         186
# Pending           60
# Started           34
# Unspecified        4
# Name: count, dtype: int64
#
#
# Value counts for column 'resolution_description':
# resolution_description
# The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.                                                                                                                                                      10096
# The Police Department responded to the complaint and took action to fix the condition.                                                                                                                                                                                                        9540
# The Police Department responded to the complaint and determined that police action was not necessary.                                                                                                                                                                                         6535
# The Police Department responded and upon arrival those responsible for the condition were gone.                                                                                                                                                                                               4627
# The Police Department issued a summons in response to the complaint.                                                                                                                                                                                                                          3222
#                                                                                                                                                                                                                                                                                              ...
# The Department of Environmental Protection inspected your complaint and repaired the problem. If the condition returns, please call 311 (or 212-639-9675 if calling from a non-New York City area code) to submit a new complaint.                                                               1
# The Department of Buildings has investigated this complaint and found that previous conditions that presented an imminent danger duing occupancy of a portion of the property have been corrected. A partial vacate order rescission has been granted.                                           1
# The Department of Environmental Protection investigated the complaint and determined that the condition is the responsibility of the home or business owner.                                                                                                                                     1
# The Department of Environmental Protection investigated the issue and found that the water source mentioned was not City water and therefore not under City jurisdiction.                                                                                                                        1
# The Department of Health and Mental Hygiene has sent official written notification to the Owner/Landlord warning them of potential violations and instructing them to correct the situation. If the situation persists 21 days after your initial complaint, please make a new complaint.        1
# Name: count, Length: 484, dtype: int64
#
#
# Value counts for column 'borough':
# borough
# BROOKLYN         21018
# QUEENS           18901
# BRONX            14844
# MANHATTAN        14239
# STATEN ISLAND     2564
# Name: count, dtype: int64
#
#
# Value counts for column 'community_board':
# community_board
# 12 BRONX            3965
# 12 MANHATTAN        2358
# 12 QUEENS           1909
# 05 BROOKLYN         1838
# 01 BROOKLYN         1828
#                     ...
# 56 BROOKLYN            5
# 95 STATEN ISLAND       4
# 84 QUEENS              3
# 82 QUEENS              3
# 27 BRONX               2
# Name: count, Length: 76, dtype: int64
#
#
# Value counts for column 'incident_zip':
# incident_zip
# 10466.0    3213
# 11226.0    1061
# 11385.0     996
# 10452.0     933
# 10467.0     913
#            ...
# 10400.0       1
# 10174.0       1
# 10279.0       1
# 10105.0       1
# 10165.0       1
# Name: count, Length: 209, dtype: int64
#
#
# Value counts for column 'city':
# city
# BROOKLYN               20139
# BRONX                  14375
# NEW YORK               12947
# STATEN ISLAND           2450
# JAMAICA                 1883
# ASTORIA                 1276
# FLUSHING                1129
# RIDGEWOOD                908
# FRESH MEADOWS            878
# QUEENS                   826
# CORONA                   801
# LONG ISLAND CITY         731
# FAR ROCKAWAY             624
# WOODSIDE                 594
# ELMHURST                 586
# JACKSON HEIGHTS          497
# SOUTH OZONE PARK         489
# OZONE PARK               469
# EAST ELMHURST            468
# SOUTH RICHMOND HILL      456
# MANHATTAN                445
# MASPETH                  426
# WOODHAVEN                393
# FOREST HILLS             383
# QUEENS VILLAGE           370
# HOWARD BEACH             323
# REGO PARK                286
# RICHMOND HILL            285
# MIDDLE VILLAGE           282
# BAYSIDE                  260
# HOLLIS                   219
# WHITESTONE               213
# SAINT ALBANS             206
# SPRINGFIELD GARDENS      200
# SUNNYSIDE                187
# COLLEGE POINT            183
# OAKLAND GARDENS          160
# ROSEDALE                 140
# KEW GARDENS              126
# CAMBRIA HEIGHTS          119
# ARVERNE                  113
# LITTLE NECK               97
# BELLEROSE                 93
# GLEN OAKS                 46
# FLORAL PARK               17
# NEW HYDE PARK             15
# BREEZY POINT               2
# Long Island City           1
# Manhattan                  1
# Queens                     1
# Name: count, dtype: int64

# %%
columns_to_check = ['complaint_type', 'descriptor', 'resolution_description', 'community_board', 'city']

# %%
# Standardize 'city' entries: trim whitespace and convert to uppercase
df_nyc_311_selected['city'] = df_nyc_311_selected['city'].str.strip().str.upper()

# Replace known outside NYC locations with 'OUTSIDE NYC'
outside = ['FLORAL PARK', 'NEW HYDE PARK', 'BREEZY POINT']
df_nyc_311_selected['city'] = df_nyc_311_selected['city'].replace(outside, 'OUTSIDE NYC')

# %%
import json

# Download the JSON file with zip code mapping to neighborhoods
with open('nyc_uhf_zipcodes.json', 'r') as f:
    uhf_data = json.load(f)

# Creating a dictionary for mapping zip codes to neighborhoods
zip_to_neighborhood = {}

for borough, neighborhoods in uhf_data.items():
    for neighborhood_info in neighborhoods:
        neighborhood_name = neighborhood_info['neighborhood']
        zip_codes = neighborhood_info['zip_codes']
        
        for zip_code in zip_codes:
            zip_to_neighborhood[zip_code] = neighborhood_name

# %%
# Create incident_zip_str column for mapping and create neighborhood column
df_nyc_311_selected['incident_zip_str'] = df_nyc_311_selected['incident_zip'].fillna(0).astype(int).astype(str).str.zfill(5)
df_nyc_311_selected.loc[df_nyc_311_selected['incident_zip'].isna(), 'incident_zip_str'] = None

df_nyc_311_selected['neighborhood'] = df_nyc_311_selected['incident_zip_str'].map(zip_to_neighborhood)

# Check the results
print(f"Mapping results:")
print(f"Number of records from neighborhood: {df_nyc_311_selected['neighborhood'].notna().sum()}")
print(f"Number of records without neighborhood: {df_nyc_311_selected['neighborhood'].isna().sum()}")
print(f"Coverage percentage: {(df_nyc_311_selected['neighborhood'].notna().sum() / len(df_nyc_311_selected) * 100):.2f}%")

# Drop the temporary incident_zip_str column
df_nyc_311_selected = df_nyc_311_selected.drop('incident_zip_str', axis=1)
# Out:
# Mapping results:
# Number of records from neighborhood: 70130
# Number of records without neighborhood: 1436
# Coverage percentage: 97.99%

# %%
# Count nubmers of complaints per neighborhood
complaints_by_neighborhood = df_nyc_311_selected.groupby(['neighborhood', 'complaint_type']).size().reset_index(name='counts').sort_values(by=['neighborhood', 'counts'], ascending=[True, False])

# %%
len(df_nyc_311_selected['neighborhood'].unique())
# Out:
# 43

# %%
len(df_median_rent_selected['areaName'].unique())
# Out:
# 198

# %%
# Load mappining areaName to neighborhood
with open('manual_map.json', 'r') as f:
    manual_map = json.load(f)

df_median_rent_selected['neighborhood'] = df_median_rent_selected['areaName'].str.lower().map(manual_map)

# %%
# Get rent stats per neighborhood
date_columns = [col for col in df_median_rent_selected.columns if col.startswith('2024') or col.startswith('2025')]

df_median_rent_selected['annual_avg_rent'] = df_median_rent_selected[date_columns].mean(axis=1)
df_median_rent_selected['annual_median_rent'] = df_median_rent_selected[date_columns].median(axis=1)
df_median_rent_selected['annual_std_rent'] = df_median_rent_selected[date_columns].std(axis=1)


neighborhood_rent_stats = df_median_rent_selected.groupby('neighborhood').agg({
    'annual_avg_rent': 'mean',
    'annual_median_rent': 'mean', 
    'annual_std_rent': 'mean'
}).reset_index()

# %%
neighborhood_rent_stats
# Out:
#                             neighborhood  annual_avg_rent  annual_median_rent  \
# 0                  Bayside - Little Neck      3093.575714         3086.700000
# 1     Bedford Stuyvesant - Crown Heights      3260.675000         3273.500000
# 2                Bensonhurst - Bay Ridge      2326.425000         2337.500000
# 3                           Borough Park      2486.600000         2500.000000
# 4                   Canarsie - Flatlands      2913.014286         2955.166667
# 5   Central Harlem - Morningside Heights      3727.275000         3709.000000
# 6                      Chelsea - Clinton      5026.983333         4999.000000
# 7          Coney Island - Sheepshead Bay      2876.062500         2882.875000
# 8                      Crotona - Tremont      2316.989064         2408.333333
# 9        Downtown - Heights - Park Slope      4058.336667         4023.500000
# 10              East Flatbush - Flatbush      2795.150000         2784.000000
# 11                           East Harlem      2945.850000         2900.000000
# 12                         East New York      3014.000000         3000.500000
# 13                  Flushing - Clearview      2727.852381         2733.875000
# 14                  Fordham - Bronx Park      2325.745833         2306.625000
# 15                         Fresh Meadows      2414.210526         2400.000000
# 16           Gramercy Park - Murray Hill      4865.500000         4800.000000
# 17                            Greenpoint      4554.800000         4512.500000
# 18              Greenwich Village - SoHo      5903.700000         5975.000000
# 19              High Bridge - Morrisania      2449.543860         2411.500000
# 20              Hunts Point - Mott Haven      3422.175000         3419.000000
# 21                               Jamaica      2596.300490         2570.125000
# 22               Kingsbridge - Riverdale      2887.200000         2884.500000
# 23            Long Island City - Astoria      3620.950000         3615.750000
# 24                       Lower Manhattan      6394.483333         6345.000000
# 25                       Northeast Bronx      2779.571429         2897.500000
# 26                  Pelham - Throgs Neck      2484.424074         2439.583333
# 27              Ridgewood - Forest Hills      2791.033333         2775.333333
# 28                              Rockaway      2636.400000         2599.000000
# 29                      Southeast Queens      2579.962963         2591.666667
# 30                      Southwest Queens      2351.956140         2331.250000
# 31                           Sunset Park      2576.750000         2576.500000
# 32        Union Square - Lower East Side      3898.850000         3886.250000
# 33                       Upper East Side      6569.650000         6362.500000
# 34                       Upper West Side      4470.300000         4441.000000
# 35           Washington Heights - Inwood      2593.025000         2500.000000
# 36                           West Queens      2646.651053         2658.000000
# 37               Williamsburg - Bushwick      3992.750000         3950.000000
#
#     annual_std_rent
# 0        158.567658
# 1        142.522108
# 2        112.853432
# 3        139.083996
# 4        239.993487
# 5        221.926682
# 6        178.906560
# 7        125.509205
# 8        398.141851
# 9        244.170679
# 10       112.627376
# 11       108.599833
# 12       161.615203
# 13       251.459776
# 14       197.501903
# 15       127.325732
# 16       299.618617
# 17       171.800864
# 18       480.939134
# 19       257.174392
# 20        44.833346
# 21       258.687223
# 22       151.175946
# 23       160.409390
# 24       579.282148
# 25       443.265654
# 26       301.464378
# 27       166.304246
# 28       180.064141
# 29       396.152336
# 30       186.357510
# 31       133.677883
# 32       308.435752
# 33       615.371152
# 34       153.289921
# 35       245.106172
# 36       149.181422
# 37       152.186797

# %%
df_merged = pd.merge(complaints_by_neighborhood, neighborhood_rent_stats, on='neighborhood', how='left')
df_merged
# Out:
#                neighborhood                  complaint_type  counts  \
# 0     Bayside - Little Neck                 Illegal Parking      87
# 1     Bayside - Little Neck               Illegal Fireworks      49
# 2     Bayside - Little Neck             Noise - Residential      33
# 3     Bayside - Little Neck                Blocked Driveway      29
# 4     Bayside - Little Neck                    Damaged Tree      26
# ...                     ...                             ...     ...
# 3647            Willowbrook                         Traffic       1
# 3648            Willowbrook  Unsanitary Animal Pvt Property       1
# 3649            Willowbrook              Vendor Enforcement       1
# 3650            Willowbrook              Water Conservation       1
# 3651            Willowbrook                   Water Quality       1
#
#       annual_avg_rent  annual_median_rent  annual_std_rent
# 0         3093.575714              3086.7       158.567658
# 1         3093.575714              3086.7       158.567658
# 2         3093.575714              3086.7       158.567658
# 3         3093.575714              3086.7       158.567658
# 4         3093.575714              3086.7       158.567658
# ...               ...                 ...              ...
# 3647              NaN                 NaN              NaN
# 3648              NaN                 NaN              NaN
# 3649              NaN                 NaN              NaN
# 3650              NaN                 NaN              NaN
# 3651              NaN                 NaN              NaN
#
# [3652 rows x 6 columns]
